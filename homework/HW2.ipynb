# %% [markdown]
# # Homework 2: More Exploratory Data Analysis
# ## Gene Expression Data and Election Polls
#
# Due: Thursday, October 2, 2014 11:59 PM
#
# <a href=https://raw.githubusercontent.com/cs109/2014/master/homework/HW2.ipynb download=HW2.ipynb> Download this assignment</a>
#
# #### Submission Instructions
# To submit your homework, create a folder named lastname_firstinitial_hw# and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code. Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. If we cannot access your work because these directions are not followed correctly, we will not grade your work.
#
#
# ---

# %% [markdown]
# ## Introduction
#
# John Tukey wrote in [Exploratory Data Analysis, 1977](http://www.amazon.com/Exploratory-Data-Analysis-Wilder-Tukey/dp/0201076160/ref=pd_bbs_sr_2/103-4466654-5303007?ie=UTF8&s=books&qid=1189739816&sr=8-2): "The greatest value of a picture is when it forces us to notice what we never expected to see." In this assignment we will continue using our exploratory data analysis tools, but apply it to new sets of data: [gene expression](http://en.wikipedia.org/wiki/Gene_expression) and polls from the [2012 Presidental Election](http://en.wikipedia.org/wiki/United_States_presidential_election,_2012) and from the [2014 Senate Midterm Elections](http://en.wikipedia.org/wiki/United_States_Senate_elections,_2014).
#
# **First**: You will use exploratory data analysis and apply the [singular value decomposition](http://en.wikipedia.org/wiki/Singular_value_decomposition) (SVD) to a gene expression data matrix to determine if the the date that the gene expression samples are processed has large effect on the variability seen in the data.
#
# **Second**: You will use the polls from the 2012 Presidential Elections to determine (1) Is there a pollster bias in presidential election polls? and (2) Is the average of polls better than just one poll?
#
# **Finally**: You will use the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to extract the polls for the current 2014 Senate Midterm Elections and provide a preliminary prediction of the result of each state.
#
# #### Data
#
# We will use the following data sets:
#
# 1. A gene expression data set called `exprs_GSE5859.csv` and sample annotation table called `sampleinfo_GSE5859.csv` which are both available on Github in the 2014_data repository: [expression data set](https://github.com/cs109/2014_data/blob/master/exprs_GSE5859.csv) and [sample annotation table](https://github.com/cs109/2014_data/blob/master/sampleinfo_GSE5859.csv).
#
# 2. Polls from the [2012 Presidential Election: Barack Obama vs Mitt Romney](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama). The polls we will use are from the [Huffington Post Pollster](http://elections.huffingtonpost.com/pollster).
#
# 3. Polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api).
#
# ---

# %% [markdown]
# ## Load Python modules

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import requests 
from StringIO import StringIO
import numpy as np
import pandas as pd # pandas
import matplotlib.pyplot as plt # module for plotting 
import datetime as dt # module for manipulating dates and times
import numpy.linalg as lin # module for performing linear algebra operations
# Out:
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Problem 1
#
# In this problem we will be using a [gene expression](http://en.wikipedia.org/wiki/Gene_expression) data set obtained from a [microarray](http://en.wikipedia.org/wiki/DNA_microarray) experiement [Read more about the specific experiment here](http://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE5859).  There are two data sets we will use:
#
# 1. The gene expression intensities where the rows represent the features on the microarray (e.g. genes) and the columsns represent the different microarray samples.
#
# 2. A table that contains the information about each of the samples (columns in the gene expression data set) such as the sex, the age, the treatment status, the date the samples were processed.  Each row represents one sample.

# %% [markdown]
# #### Problem 1(a)
# Read in the two files from Github: [exprs_GSE5859.csv](https://github.com/cs109/2014_data/blob/master/exprs_GSE5859.csv) and [sampleinfo_GSE5859.csv](https://github.com/cs109/2014_data/blob/master/sampleinfo_GSE5859.csv) as pandas DataFrames called `exprs` and `sampleinfo`. Use the gene names as the index of the `exprs` DataFrame.

# %%
#your code here
exprs = pd.read_csv('https://raw.githubusercontent.com/cs109/2014_data/master/exprs_GSE5859.csv')
sampleinfo = pd.read_csv('https://raw.githubusercontent.com/cs109/2014_data/master/sampleinfo_GSE5859.csv')

# %% [markdown]
# Make sure the order of the columns in the gene expression DataFrame match the order of file names in the sample annotation DataFrame. If the order of the columns the `exprs` DataFrame do not match the order of the file names in the `sampleinfo` DataFrame, reorder the columns in the `exprs` DataFrame.
#
# **Note**: The column names of the gene expression DataFrame are the filenames of the orignal files from which these data were obtained.
#
# **Hint**: The method `list.index(x)` [[read here](https://docs.python.org/2/tutorial/datastructures.html)] can be used to return the index in the list of the first item whose value is x. It is an error if there is no such item. To check if the order of the columns in `exprs` matches the order of the rows in `sampleinfo`, you can check using the method `.all()` on a Boolean or list of Booleans:
#
# Example code: `(exprs.columns == sampleinfo.filename).all()`

# %%
print exprs.head()
sampleinfo.head()
# Out:
#   Unnamed: 0  GSM25581.CEL.gz  GSM25681.CEL.gz  GSM136524.CEL.gz  \
# 0  1007_s_at         6.333951         5.736190          6.156754
# 1    1053_at         7.255622         7.399993          7.491967
# 2     117_at         5.760106         4.825169          5.039387
# 3     121_at         6.935451         7.025210          7.543667
# 4  1255_g_at         3.597872         3.108801          3.128269
#
#    GSM136707.CEL.gz  GSM25553.CEL.gz  GSM136676.CEL.gz  GSM136711.CEL.gz  \
# 0          6.513010         6.061013          6.506493          6.863426
# 1          7.006123         7.250995          7.082581          6.842236
# 2          5.414160         5.205697          5.300078          5.099337
# 3          7.959781         7.223323          8.006816          8.102504
# 4          3.364947         3.125909          3.186834          3.311022
#
#    GSM136542.CEL.gz  GSM136535.CEL.gz        ...         GSM48650.CEL.gz  \
# 0          6.369645          6.646321        ...                7.082636
# 1          7.048487          7.042361        ...                6.599718
# 2          5.156459          5.736109        ...                6.231457
# 3          7.434617          7.532321        ...                8.215096
# 4          3.092042          3.167737        ...                3.331424
#
#    GSM25687.CEL.gz  GSM25685.CEL.gz  GSM136549.CEL.gz  GSM25427.CEL.gz  \
# 0         6.315866         7.010165          6.460107         6.122355
# 1         7.412731         7.274429          6.928642         7.168782
# 2         5.240717         5.275062          5.759827         5.409720
# 3         7.677593         7.923624          7.219401         7.432338
# 4         3.043856         3.151900          3.132253         3.250600
#
#    GSM25525.CEL.gz  GSM25349.CEL.gz  GSM136727.CEL.gz  GSM25626.CEL.gz  \
# 0         6.330314         6.627014          6.133068         6.419444
# 1         7.235648         6.939184          7.280781         6.351776
# 2         5.491938         5.113570          5.401876         5.537605
# 3         6.785174         7.833862          7.607461         7.302935
# 4         2.984125         3.152269          3.225123         3.222731
#
#    GSM136725.CEL.gz
# 0          6.488579
# 1          7.517410
# 2          5.247190
# 3          7.331864
# 4          3.175846
#
# [5 rows x 209 columns]
#   ethnicity        date         filename sex
# 0       CEU  2003-02-04  GSM25349.CEL.gz   M
# 1       CEU  2003-02-04  GSM25350.CEL.gz   M
# 2       CEU  2002-12-17  GSM25356.CEL.gz   M
# 3       CEU  2003-01-30  GSM25357.CEL.gz   M
# 4       CEU  2003-01-03  GSM25358.CEL.gz   M

# %%
test = ['sdsds']
test2 = [col for col in sampleinfo.filename]
test
# Out:
# ['sdsds']

# %%
#your code here
print exprs.shape
print sampleinfo.shape
print len(exprs.columns[1:])
print len(sampleinfo.filename)
sum(exprs.columns[1:] != sampleinfo.filename)
(exprs.columns[1:] == sampleinfo.filename).all()
### concatenate two lists: use +
exprs = exprs[['Unnamed: 0'] + [col for col in sampleinfo.filename]]
# Out:
# (8793, 209)
# (208, 4)
# 208
# 208

# %% [markdown]
# Show the head of the two tables: `exprs` and `sampleinfo`.

# %%
#your code here
exprs.head()
# Out:
#   Unnamed: 0  GSM25349.CEL.gz  GSM25350.CEL.gz  GSM25356.CEL.gz  \
# 0  1007_s_at         6.627014         6.249807         5.934128
# 1    1053_at         6.939184         6.818038         7.047962
# 2     117_at         5.113570         5.074096         5.371201
# 3     121_at         7.833862         7.780682         7.458197
# 4  1255_g_at         3.152269         3.111747         3.018932
#
#    GSM25357.CEL.gz  GSM25358.CEL.gz  GSM25359.CEL.gz  GSM25360.CEL.gz  \
# 0         6.145268         6.091270         6.041186         6.050375
# 1         7.422477         7.272361         7.128216         6.750719
# 2         5.266550         5.342047         5.063876         5.315898
# 3         7.655948         7.546555         7.072670         7.092984
# 4         3.154545         3.107954         3.224284         3.114241
#
#    GSM25361.CEL.gz  GSM25377.CEL.gz        ...         GSM136719.CEL.gz  \
# 0         6.063847         6.226106        ...                 6.466445
# 1         6.836287         6.738022        ...                 7.032885
# 2         5.483652         6.689444        ...                 5.661112
# 3         6.954225         7.489785        ...                 7.769734
# 4         3.044975         3.304038        ...                 3.257484
#
#    GSM136720.CEL.gz  GSM136721.CEL.gz  GSM136722.CEL.gz  GSM136723.CEL.gz  \
# 0          6.533592          6.631492          6.513362          6.440706
# 1          7.156344          7.018025          6.973322          6.884738
# 2          5.127260          5.151840          5.505602          5.687689
# 3          7.815864          7.683279          7.883231          7.913621
# 4          3.339234          3.298384          3.150654          3.344501
#
#    GSM136724.CEL.gz  GSM136725.CEL.gz  GSM136726.CEL.gz  GSM136727.CEL.gz  \
# 0          6.704324          6.488579          6.809481          6.133068
# 1          7.120898          7.517410          7.200596          7.280781
# 2          4.942651          5.247190          5.237239          5.401876
# 3          7.834196          7.331864          7.357102          7.607461
# 4          3.230285          3.175846          3.105092          3.225123
#
#    GSM136729.CEL.gz
# 0          6.155473
# 1          7.111583
# 2          5.302628
# 3          7.456453
# 4          3.090149
#
# [5 rows x 209 columns]

# %%
sampleinfo.head()
# Out:
#   ethnicity        date         filename sex
# 0       CEU  2003-02-04  GSM25349.CEL.gz   M
# 1       CEU  2003-02-04  GSM25350.CEL.gz   M
# 2       CEU  2002-12-17  GSM25356.CEL.gz   M
# 3       CEU  2003-01-30  GSM25357.CEL.gz   M
# 4       CEU  2003-01-03  GSM25358.CEL.gz   M

# %% [markdown]
# #### Problem 1(b)
#
# Extract the year and month as integers from the `sampleinfo` table.
#
# **Hint**: To convert a Series or a column of a pandas DataFrame that contains a date-like object, you can use the `to_datetime` function [[read here](http://pandas.pydata.org/pandas-docs/stable/timeseries.html)].  This will create a `DatetimeIndex` which can be used to extract the month and year for each row in the DataFrame.

# %%
#your code here
print sampleinfo.dtypes
sampleinfo['date'] = pd.to_datetime(sampleinfo['date'])
# Out:
# ethnicity    object
# date         object
# filename     object
# sex          object
# dtype: object

# %%
print sampleinfo.dtypes
## to extract part of dates first convert series to datetime index
sampleinfo['month'] = pd.DatetimeIndex(sampleinfo['date']).month
sampleinfo['year'] = pd.DatetimeIndex(sampleinfo['date']).year
print sampleinfo.dtypes
# Out:
# ethnicity            object
# date         datetime64[ns]
# filename             object
# sex                  object
# dtype: object
# ethnicity            object
# date         datetime64[ns]
# filename             object
# sex                  object
# month                 int32
# year                  int32
# dtype: object

# %% [markdown]
# #### Problem 1(c)
#
# Convert the dates in the `date` column from the `sampleinfo` table into days since October 31, 2002. Add a column to the `sampleinfo` DataFrame titled `elapsedInDays` containing the days since October 31, 2002.  Show the head of the `sampleinfo` DataFrame which includes the new column.
#
# **Hint**: Use the `datetime` module to create a new `datetime` object for the specific date October 31, 2002. Then, subtract the October 31, 2002 date from each date from the `date` column in the `sampleinfo` DataFrame.

# %%
dt.datetime.strptime('2002-10-31', '%Y-%m-%d')
# Out:
# datetime.datetime(2002, 10, 31, 0, 0)

# %%
#your code here
sampleinfo['elapsedInDays'] = sampleinfo['date'] - dt.datetime.strptime('2002-10-31', '%Y-%m-%d')

# %%
sampleinfo.head(10)
# Out:
#   ethnicity       date         filename sex  month  year  elapsedInDays
# 0       CEU 2003-02-04  GSM25349.CEL.gz   M      2  2003        96 days
# 1       CEU 2003-02-04  GSM25350.CEL.gz   M      2  2003        96 days
# 2       CEU 2002-12-17  GSM25356.CEL.gz   M     12  2002        47 days
# 3       CEU 2003-01-30  GSM25357.CEL.gz   M      1  2003        91 days
# 4       CEU 2003-01-03  GSM25358.CEL.gz   M      1  2003        64 days
# 5       CEU 2003-01-16  GSM25359.CEL.gz   M      1  2003        77 days
# 6       CEU 2003-01-03  GSM25360.CEL.gz   F      1  2003        64 days
# 7       CEU 2003-02-04  GSM25361.CEL.gz   M      2  2003        96 days
# 8       CEU 2002-12-17  GSM25377.CEL.gz   M     12  2002        47 days
# 9       CEU 2002-12-17  GSM25378.CEL.gz   M     12  2002        47 days

# %% [markdown]
# #### Problem 1(d)
#
# Use exploratory analysis and the singular value decomposition (SVD) of the gene expression data matrix to determine if the date the samples were processed has large effect on the variability seen in the data or if it is just ethnicity (which is confounded with date).
#
# **Hint**: See the end of the [lecture from 9/23/2014 for help with SVD](http://nbviewer.ipython.org/github/cs109/2014/blob/master/lectures/lecture07/data_scraping_transcript.ipynb).
#
# First subset the the `sampleinfo` DataFrame to include only the CEU ethnicity.  Call this new subsetted DataFrame `sampleinfoCEU`.  Show the head of `sampleinfoCEU` DataFrame.

# %%
## set index
exprs = exprs.set_index('Unnamed: 0')
exprs.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-bc12b5d2fbd3> in <module>()
#       1 ## set index
# ----> 2 exprs = exprs.set_index('Unnamed: 0')
#       3 exprs.head()
#       4 exprs.iloc[0]
#
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2897                 names.append(None)
#    2898             else:
# -> 2899                 level = frame[col]._values
#    2900                 names.append(col)
#    2901                 if drop:
#
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2055             return self._getitem_multilevel(key)
#    2056         else:
# -> 2057             return self._getitem_column(key)
#    2058
#    2059     def _getitem_column(self, key):
#
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2062         # get column
#    2063         if self.columns.is_unique:
# -> 2064             return self._get_item_cache(key)
#    2065
#    2066         # duplicate columns & possible reduce dimensionality
#
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3518
#    3519             if not isnull(item):
# -> 3520                 loc = self.items.get_loc(item)
#    3521             else:
#    3522                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/lorenzofontana/anaconda/lib/python2.7/site-packages/pandas/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2104                 return self._engine.get_loc(key)
#    2105             except KeyError:
# -> 2106                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2107
#    2108         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4160)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4024)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13161)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13115)()
#
# KeyError: 'Unnamed: 0'

# %%
exprs.head()
# Out:
#             GSM25349.CEL.gz  GSM25350.CEL.gz  GSM25356.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.627014         6.249807         5.934128
# 1053_at            6.939184         6.818038         7.047962
# 117_at             5.113570         5.074096         5.371201
# 121_at             7.833862         7.780682         7.458197
# 1255_g_at          3.152269         3.111747         3.018932
#
#             GSM25357.CEL.gz  GSM25358.CEL.gz  GSM25359.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.145268         6.091270         6.041186
# 1053_at            7.422477         7.272361         7.128216
# 117_at             5.266550         5.342047         5.063876
# 121_at             7.655948         7.546555         7.072670
# 1255_g_at          3.154545         3.107954         3.224284
#
#             GSM25360.CEL.gz  GSM25361.CEL.gz  GSM25377.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.050375         6.063847         6.226106
# 1053_at            6.750719         6.836287         6.738022
# 117_at             5.315898         5.483652         6.689444
# 121_at             7.092984         6.954225         7.489785
# 1255_g_at          3.114241         3.044975         3.304038
#
#             GSM25378.CEL.gz        ...         GSM136719.CEL.gz  \
# Unnamed: 0                         ...
# 1007_s_at          6.358282        ...                 6.466445
# 1053_at            7.367895        ...                 7.032885
# 117_at             6.482782        ...                 5.661112
# 121_at             7.388539        ...                 7.769734
# 1255_g_at          2.887919        ...                 3.257484
#
#             GSM136720.CEL.gz  GSM136721.CEL.gz  GSM136722.CEL.gz  \
# Unnamed: 0
# 1007_s_at           6.533592          6.631492          6.513362
# 1053_at             7.156344          7.018025          6.973322
# 117_at              5.127260          5.151840          5.505602
# 121_at              7.815864          7.683279          7.883231
# 1255_g_at           3.339234          3.298384          3.150654
#
#             GSM136723.CEL.gz  GSM136724.CEL.gz  GSM136725.CEL.gz  \
# Unnamed: 0
# 1007_s_at           6.440706          6.704324          6.488579
# 1053_at             6.884738          7.120898          7.517410
# 117_at              5.687689          4.942651          5.247190
# 121_at              7.913621          7.834196          7.331864
# 1255_g_at           3.344501          3.230285          3.175846
#
#             GSM136726.CEL.gz  GSM136727.CEL.gz  GSM136729.CEL.gz
# Unnamed: 0
# 1007_s_at           6.809481          6.133068          6.155473
# 1053_at             7.200596          7.280781          7.111583
# 117_at              5.237239          5.401876          5.302628
# 121_at              7.357102          7.607461          7.456453
# 1255_g_at           3.105092          3.225123          3.090149
#
# [5 rows x 208 columns]

# %%
#your code here
sampleinfoCEU = sampleinfo[sampleinfo['ethnicity'] == 'CEU']
print sampleinfo.shape, sampleinfoCEU.shape
sampleinfoCEU.head()
# Out:
# (208, 7) (102, 7)
#   ethnicity       date         filename sex  month  year  elapsedInDays
# 0       CEU 2003-02-04  GSM25349.CEL.gz   M      2  2003        96 days
# 1       CEU 2003-02-04  GSM25350.CEL.gz   M      2  2003        96 days
# 2       CEU 2002-12-17  GSM25356.CEL.gz   M     12  2002        47 days
# 3       CEU 2003-01-30  GSM25357.CEL.gz   M      1  2003        91 days
# 4       CEU 2003-01-03  GSM25358.CEL.gz   M      1  2003        64 days

# %% [markdown]
# Next, subset the `exprs` DataFrame to only include the samples with the CEU ethnicity. Name this new subsetted DataFrame `exprsCEU`. Show the head of the `exprsCEU` DataFrame.

# %%
#your code here
exprsCEU = exprs[[col for col in sampleinfoCEU.filename]]
print exprs.shape, exprsCEU.shape
exprsCEU.head()
# Out:
# (8793, 208) (8793, 102)
#             GSM25349.CEL.gz  GSM25350.CEL.gz  GSM25356.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.627014         6.249807         5.934128
# 1053_at            6.939184         6.818038         7.047962
# 117_at             5.113570         5.074096         5.371201
# 121_at             7.833862         7.780682         7.458197
# 1255_g_at          3.152269         3.111747         3.018932
#
#             GSM25357.CEL.gz  GSM25358.CEL.gz  GSM25359.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.145268         6.091270         6.041186
# 1053_at            7.422477         7.272361         7.128216
# 117_at             5.266550         5.342047         5.063876
# 121_at             7.655948         7.546555         7.072670
# 1255_g_at          3.154545         3.107954         3.224284
#
#             GSM25360.CEL.gz  GSM25361.CEL.gz  GSM25377.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.050375         6.063847         6.226106
# 1053_at            6.750719         6.836287         6.738022
# 117_at             5.315898         5.483652         6.689444
# 121_at             7.092984         6.954225         7.489785
# 1255_g_at          3.114241         3.044975         3.304038
#
#             GSM25378.CEL.gz        ...         GSM48658.CEL.gz  \
# Unnamed: 0                         ...
# 1007_s_at          6.358282        ...                6.501510
# 1053_at            7.367895        ...                7.066686
# 117_at             6.482782        ...                5.600514
# 121_at             7.388539        ...                7.437535
# 1255_g_at          2.887919        ...                3.009983
#
#             GSM48660.CEL.gz  GSM48661.CEL.gz  GSM48662.CEL.gz  \
# Unnamed: 0
# 1007_s_at          6.558100         6.618286         6.869995
# 1053_at            7.386702         6.407958         7.089180
# 117_at             5.232676         5.630720         4.944748
# 121_at             7.714650         7.416252         7.746448
# 1255_g_at          3.151203         3.199709         3.159496
#
#             GSM48663.CEL.gz  GSM48664.CEL.gz  GSM48665.CEL.gz  \
# Unnamed: 0
# 1007_s_at          5.981000         6.403285         6.248702
# 1053_at            7.120923         7.018998         7.155419
# 117_at             5.275577         5.770358         5.616842
# 121_at             8.001434         7.626723         7.452299
# 1255_g_at          3.149710         3.242780         3.433125
#
#             GSM136725.CEL.gz  GSM136726.CEL.gz  GSM136727.CEL.gz
# Unnamed: 0
# 1007_s_at           6.488579          6.809481          6.133068
# 1053_at             7.517410          7.200596          7.280781
# 117_at              5.247190          5.237239          5.401876
# 121_at              7.331864          7.357102          7.607461
# 1255_g_at           3.175846          3.105092          3.225123
#
# [5 rows x 102 columns]

# %% [markdown]
# Check to make sure the order of the columns in the `exprsCEU` DataFrame matches the rows in the `sampleinfoCEU` DataFrame.

# %%
#your code here
(exprsCEU.columns == sampleinfoCEU.filename).all()
# Out:
# True

# %% [markdown]
# Compute the average gene expression intensity in the `exprsCEU` DataFrame across all the samples. For each sample in the `exprsCEU` DataFrame, subtract the average gene expression intensity from each of the samples. Show the head of the mean normalized gene expression data.

# %%
avg_exprsCEU_intensity = exprsCEU.mean(axis = 1)
avg_exprsCEU_intensity
# Out:
# Unnamed: 0
# 1007_s_at                       6.261955
# 1053_at                         7.075217
# 117_at                          5.604127
# 121_at                          7.415835
# 1255_g_at                       3.133934
# 1294_at                         7.443822
# 1316_at                         4.194175
# 1320_at                         3.634596
# 1431_at                         2.720416
# 1438_at                         5.098670
# 1487_at                         6.619314
# 1494_f_at                       5.073638
# 1598_g_at                       7.007441
# 160020_at                       5.949351
# 1729_at                         7.194062
# 177_at                          4.939944
# 1773_at                         5.129351
# 1861_at                         4.949171
# 200000_s_at                     9.089661
# 200001_at                       9.503577
# 200002_at                      11.619209
# 200003_s_at                    11.753016
# 200004_at                      10.162551
# 200005_at                       9.882220
# 200006_at                      10.794186
# 200007_at                       9.984963
# 200008_s_at                     8.716425
# 200009_at                      10.203574
# 200010_at                      11.208672
# 200011_s_at                     8.770979
#                                  ...
# AFFX-HUMISGF3A/M97935_5_at      5.229770
# AFFX-HUMISGF3A/M97935_MA_at     8.106303
# AFFX-HUMISGF3A/M97935_MB_at     7.469021
# AFFX-HUMRGE/M10098_3_at         5.155155
# AFFX-HUMRGE/M10098_5_at         3.560369
# AFFX-HUMRGE/M10098_M_at         3.342100
# AFFX-M27830_3_at                5.596485
# AFFX-M27830_5_at                4.751642
# AFFX-M27830_M_at                7.309361
# AFFX-r2-Bs-dap-3_at             2.481553
# AFFX-r2-Bs-dap-5_at             2.977755
# AFFX-r2-Bs-dap-M_at             2.446981
# AFFX-r2-Bs-lys-3_at             2.544446
# AFFX-r2-Bs-lys-5_at             2.554993
# AFFX-r2-Bs-lys-M_at             2.851704
# AFFX-r2-Bs-phe-3_at             3.437714
# AFFX-r2-Bs-phe-5_at             2.474713
# AFFX-r2-Bs-phe-M_at             2.867071
# AFFX-r2-Bs-thr-3_s_at           3.736757
# AFFX-r2-Bs-thr-5_s_at           3.486868
# AFFX-r2-Bs-thr-M_s_at           3.330253
# AFFX-r2-Ec-bioB-3_at            6.118194
# AFFX-r2-Ec-bioB-5_at            5.637635
# AFFX-r2-Ec-bioB-M_at            5.516533
# AFFX-r2-Ec-bioC-3_at            7.804273
# AFFX-r2-Ec-bioC-5_at            7.553864
# AFFX-r2-Ec-bioD-3_at           10.368216
# AFFX-r2-Ec-bioD-5_at            9.742619
# AFFX-r2-P1-cre-3_at             8.604434
# AFFX-r2-P1-cre-5_at             9.167922
# dtype: float64

# %%
#your code here
print exprsCEU.head()
#exprsCEU[exprsCEU.columns[1:]].sub(exprsCEU[exprsCEU.columns[1:]].mean(axis = 1), axis = 0)
# this is correct, whatever:
exprsCEU = exprsCEU.sub(exprsCEU.mean(axis = 1), axis = 0)
exprsCEU
# Out:
#             GSM25349.CEL.gz  GSM25350.CEL.gz  GSM25356.CEL.gz  \
# Unnamed: 0
# 1007_s_at          0.365059        -0.012149        -0.327827
# 1053_at           -0.136032        -0.257178        -0.027254
# 117_at            -0.490556        -0.530031        -0.232926
# 121_at             0.418026         0.364847         0.042362
# 1255_g_at          0.018335        -0.022187        -0.115002
#
#             GSM25357.CEL.gz  GSM25358.CEL.gz  GSM25359.CEL.gz  \
# Unnamed: 0
# 1007_s_at         -0.116687        -0.170685        -0.220769
# 1053_at            0.347260         0.197144         0.053000
# 117_at            -0.337577        -0.262080        -0.540250
# 121_at             0.240113         0.130720        -0.343165
# 1255_g_at          0.020611        -0.025980         0.090351
#
#             GSM25360.CEL.gz  GSM25361.CEL.gz  GSM25377.CEL.gz  \
# Unnamed: 0
# 1007_s_at         -0.211580        -0.198109        -0.035849
# 1053_at           -0.324497        -0.238930        -0.337195
# 117_at            -0.288228        -0.120475         1.085317
# 121_at            -0.322852        -0.461611         0.073949
# 1255_g_at         -0.019693        -0.088959         0.170104
#
#             GSM25378.CEL.gz        ...         GSM48658.CEL.gz  \
# Unnamed: 0                         ...
# AFFX-r2-Bs-dap-3_at                -0.007546        -0.088438
# AFFX-r2-Bs-dap-5_at                -0.108422         0.055474
# AFFX-r2-Bs-dap-M_at                 0.166430        -0.005266
# AFFX-r2-Bs-lys-3_at                 0.184606         0.181267
# AFFX-r2-Bs-lys-5_at                 0.062136         0.242112
# AFFX-r2-Bs-lys-M_at                -0.086993         0.098093
# AFFX-r2-Bs-phe-3_at                 0.334032         0.207800
# AFFX-r2-Bs-phe-5_at                -0.059215         0.232360
# AFFX-r2-Bs-phe-M_at                -0.132585         0.294544
# AFFX-r2-Bs-thr-3_s_at               0.027679         0.172475
# AFFX-r2-Bs-thr-5_s_at               0.144425        -0.139312
# AFFX-r2-Bs-thr-M_s_at               0.318455         0.268045
# AFFX-r2-Ec-bioB-3_at                0.317745         0.287049
# AFFX-r2-Ec-bioB-5_at                0.254570        -0.476317
# AFFX-r2-Ec-bioB-M_at                0.406008         0.061072
# AFFX-r2-Ec-bioC-3_at                0.477943         0.200540
# AFFX-r2-Ec-bioC-5_at                0.689271         0.143489
# AFFX-r2-Ec-bioD-3_at               -0.103065        -0.773710
# AFFX-r2-Ec-bioD-5_at               -0.173098        -0.687158
# AFFX-r2-P1-cre-3_at                 2.297353         1.551632
# AFFX-r2-P1-cre-5_at                 2.228507         1.903253
#
#                              GSM25356.CEL.gz  GSM25357.CEL.gz  \
# Unnamed: 0
# 1007_s_at                          -0.327827        -0.116687
# 1053_at                            -0.027254         0.347260
# 117_at                             -0.232926        -0.337577
# 121_at                              0.042362         0.240113
# 1255_g_at                          -0.115002         0.020611
# 1294_at                            -0.144484        -0.358229
# 1316_at                             0.067993         0.145587
# 1320_at                             0.063070         0.157686
# 1431_at                            -0.107353        -0.076311
# 1438_at                            -0.132075         0.215870
# 1487_at                             0.181143         0.236857
# 1494_f_at                          -0.025607         0.272305
# 1598_g_at                          -0.073062         0.114208
# 160020_at                           0.099196         0.224595
# 1729_at                             0.258846         0.126402
# 177_at                             -0.592644        -0.693283
# 1773_at                             0.223669         0.190489
# 1861_at                            -0.015046         0.140935
# 200000_s_at                         0.044196        -0.296536
# 200001_at                          -0.183466        -0.091414
# 200002_at                           0.053480        -0.098700
# 200003_s_at                         0.084254         0.004447
# 200004_at                           0.328949         0.401411
# 200005_at                           0.008975         0.125877
# 200006_at                          -0.063443         0.231342
# 200007_at                           0.107862        -0.017397
# 200008_s_at                         0.134401         0.027920
# 200009_at                           0.111441         0.018405
# 200010_at                           0.070940        -0.048074
# 200011_s_at                        -0.390970        -0.468401
# ...                                      ...              ...
# AFFX-HUMISGF3A/M97935_5_at         -0.311803         0.342901
# AFFX-HUMISGF3A/M97935_MA_at        -0.265348        -0.074176
# AFFX-HUMISGF3A/M97935_MB_at        -0.277405        -0.361502
# AFFX-HUMRGE/M10098_3_at             0.216697         1.119571
# AFFX-HUMRGE/M10098_5_at             0.154681         0.597670
# AFFX-HUMRGE/M10098_M_at             0.240141         1.156476
# AFFX-M27830_3_at                   -0.127301         0.140387
# AFFX-M27830_5_at                    0.376513         0.863683
# AFFX-M27830_M_at                    0.343009         0.125413
# AFFX-r2-Bs-dap-3_at                 0.065688        -0.057105
# AFFX-r2-Bs-dap-5_at                -0.046521        -0.004410
# AFFX-r2-Bs-dap-M_at                 0.020294         0.199283
# AFFX-r2-Bs-lys-3_at                -0.178093         0.105312
# AFFX-r2-Bs-lys-5_at                -0.129907        -0.021622
# AFFX-r2-Bs-lys-M_at                 0.223080         0.227283
# AFFX-r2-Bs-phe-3_at                -0.214377        -0.268211
# AFFX-r2-Bs-phe-5_at                 0.100419         0.013229
# AFFX-r2-Bs-phe-M_at                -0.273473        -0.134652
# AFFX-r2-Bs-thr-3_s_at               0.010000        -0.054812
# AFFX-r2-Bs-thr-5_s_at              -0.363676         0.049250
# AFFX-r2-Bs-thr-M_s_at              -0.317836        -0.014733
# AFFX-r2-Ec-bioB-3_at                1.500017        -0.924906
# AFFX-r2-Ec-bioB-5_at                1.507281        -1.071036
# AFFX-r2-Ec-bioB-M_at                1.775399        -0.934528
# AFFX-r2-Ec-bioC-3_at                1.315710        -0.853900
# AFFX-r2-Ec-bioC-5_at                1.487463        -1.157919
# AFFX-r2-Ec-bioD-3_at                0.715131        -1.414810
# AFFX-r2-Ec-bioD-5_at                0.731987        -1.694287
# AFFX-r2-P1-cre-3_at                 2.963175         1.271533
# AFFX-r2-P1-cre-5_at                 2.811175         1.311828
#
#                              GSM25358.CEL.gz  GSM25359.CEL.gz  \
# Unnamed: 0
# 1007_s_at                          -0.170685        -0.220769
# 1053_at                             0.197144         0.053000
# 117_at                             -0.262080        -0.540250
# 121_at                              0.130720        -0.343165
# 1255_g_at                          -0.025980         0.090351
# 1294_at                             0.148120        -0.002672
# 1316_at                            -0.071506        -0.134743
# 1320_at                            -0.128003        -0.166288
# 1431_at                             0.034343        -0.222854
# 1438_at                            -0.174145        -0.055737
# 1487_at                             0.228301        -0.079867
# 1494_f_at                          -0.098069         0.055297
# 1598_g_at                          -0.075823        -0.108868
# 160020_at                          -0.096015        -0.329435
# 1729_at                            -0.024690         0.010292
# 177_at                             -0.503888        -0.531432
# 1773_at                            -0.157534        -0.060803
# 1861_at                            -0.378767         0.030327
# 200000_s_at                        -0.079813        -0.047802
# 200001_at                           0.003521        -0.209757
# 200002_at                          -0.000676        -0.033799
# 200003_s_at                        -0.136574         0.016541
# 200004_at                           0.387344         0.140313
# 200005_at                          -0.130880        -0.186336
# 200006_at                           0.225170        -0.013489
# 200007_at                           0.284136         0.094105
# 200008_s_at                        -0.172401        -0.424880
# 200009_at                           0.160342        -0.092886
# 200010_at                          -0.042357         0.013690
# 200011_s_at                         0.106426         0.088191
# ...                                      ...              ...
# AFFX-HUMISGF3A/M97935_5_at         -0.358335        -0.826518
# AFFX-HUMISGF3A/M97935_MA_at        -0.609643        -0.998283
# AFFX-HUMISGF3A/M97935_MB_at        -0.389006        -0.517594
# AFFX-HUMRGE/M10098_3_at             0.081444         0.978859
# AFFX-HUMRGE/M10098_5_at             0.122163         0.975585
# AFFX-HUMRGE/M10098_M_at             0.289864         1.411578
# AFFX-M27830_3_at                   -0.002687        -0.510673
# AFFX-HUMRGE/M10098_M_at             0.058124        -0.145372
# AFFX-M27830_3_at                   -0.233302         0.141354
# AFFX-M27830_5_at                    1.135785         0.386406
# AFFX-M27830_M_at                    0.777374         0.640340
# AFFX-r2-Bs-dap-3_at                 0.021360         0.423001
# AFFX-r2-Bs-dap-5_at                 0.097272         0.304650
# AFFX-r2-Bs-dap-M_at                 0.130023         0.033860
# AFFX-r2-Bs-lys-3_at                -0.034743         0.020322
# AFFX-r2-Bs-lys-5_at                 0.206675         0.101046
# AFFX-r2-Bs-lys-M_at                -0.187207        -0.092234
# AFFX-r2-Bs-phe-3_at                 0.181680        -0.012147
# AFFX-r2-Bs-phe-5_at                 0.040044         0.033310
# AFFX-r2-Bs-phe-M_at                -0.005145         0.458716
# AFFX-r2-Bs-thr-3_s_at              -0.375402        -0.481073
# AFFX-r2-Bs-thr-5_s_at               0.056481         0.008144
# AFFX-r2-Bs-thr-M_s_at              -0.208485        -0.038857
# AFFX-r2-Ec-bioB-3_at                0.969347        -0.269619
# AFFX-r2-Ec-bioB-5_at                1.137766        -0.485535
# AFFX-r2-Ec-bioB-M_at                1.206981        -0.792252
# AFFX-r2-Ec-bioC-3_at                0.979937        -0.233020
# AFFX-r2-Ec-bioC-5_at                1.011288        -0.317811
# AFFX-r2-Ec-bioD-3_at                0.093629        -1.339476
# AFFX-r2-Ec-bioD-5_at                0.261006        -1.392788
# AFFX-r2-P1-cre-3_at                 2.566503         1.123319
# AFFX-r2-P1-cre-5_at                 2.429209         0.813965
#
#                              GSM25377.CEL.gz  GSM25378.CEL.gz  \
# Unnamed: 0
# 1007_s_at                          -0.035849         0.096327
# 1053_at                            -0.337195         0.292678
# 117_at                              1.085317         0.878655
# 121_at                              0.073949        -0.027296
# 1255_g_at                           0.170104        -0.246015
# 1294_at                             0.065287         0.158625
# 1316_at                             0.188815         0.032092
# 1320_at                             0.169234        -0.120838
# 1431_at                             0.110924        -0.084994
# 1438_at                             0.201126        -0.288742
# 1487_at                             0.475530         0.251829
# 1494_f_at                          -0.403949        -0.329392
# 1598_g_at                           0.208469        -0.055337
# 160020_at                           0.295643         0.008664
# 1729_at                            -0.563955        -0.319282
# 177_at                             -0.347105        -0.719461
# 1773_at                            -0.024958        -0.168616
# 1861_at                            -0.439450         0.112731
# 200000_s_at                         0.229080         0.310567
# 200001_at                           0.079224         0.202288
# 200002_at                          -0.128392        -0.275066
# 200003_s_at                        -0.209540        -0.020195
# 200004_at                          -0.015664         0.333287
# 200005_at                          -0.089762         0.094428
# 200006_at                          -0.029754         0.086210
# 200007_at                          -0.104029        -0.117367
# 200008_s_at                         0.062422         0.638781
# 200009_at                           0.107910         0.542054
# 200010_at                          -0.016832        -0.281493
# 200011_s_at                        -0.041180        -0.006584
# ...                                      ...              ...
# AFFX-HUMISGF3A/M97935_5_at         -0.409847        -1.796190
# AFFX-HUMISGF3A/M97935_MA_at        -0.231392        -0.159254
# AFFX-HUMISGF3A/M97935_MB_at        -0.331517         0.388779
# AFFX-HUMRGE/M10098_3_at            -0.340349        -0.609961
# AFFX-HUMRGE/M10098_5_at             0.315121        -0.591281
# AFFX-HUMRGE/M10098_M_at             0.142198        -0.450493
# AFFX-M27830_3_at                   -0.316604        -0.195318
# AFFX-M27830_5_at                   -0.604198        -1.027788
# AFFX-M27830_M_at                   -0.201156        -0.715858
# AFFX-r2-Bs-dap-3_at                 0.465380        -0.178056
# AFFX-r2-Bs-dap-5_at                -0.098667        -0.137996
# AFFX-r2-Bs-dap-M_at                 0.304422        -0.008082
# AFFX-r2-Bs-lys-3_at                 0.122846         0.037691
# AFFX-r2-Bs-lys-5_at                -0.078299        -0.030250
# AFFX-r2-Bs-lys-M_at                 0.249056        -0.092858
# AFFX-r2-Bs-phe-3_at                 0.250878        -0.132403
# AFFX-r2-Bs-phe-5_at                 0.163212        -0.073312
# AFFX-r2-Bs-phe-M_at                 0.058483        -0.278345
# AFFX-r2-Bs-thr-3_s_at               0.061821        -0.263999
# AFFX-r2-Bs-thr-5_s_at              -0.247859        -0.101929
# AFFX-r2-Bs-thr-M_s_at               0.008859        -0.166909
# AFFX-r2-Ec-bioB-3_at                1.558319        -0.333858
# AFFX-r2-Ec-bioB-5_at                1.543445        -0.395855
# AFFX-r2-Ec-bioB-M_at                1.689112         0.116391
# AFFX-r2-Ec-bioC-3_at                1.325175         0.270186
# AFFX-r2-Ec-bioC-5_at                1.526027        -0.110209
# AFFX-r2-Ec-bioD-3_at                0.971557        -0.633119
# AFFX-r2-Ec-bioD-5_at                0.990541        -1.103567
# AFFX-r2-P1-cre-3_at                 2.982351         1.708631
# AFFX-r2-P1-cre-5_at                 2.976873         1.862993
#
#                                    ...         GSM48658.CEL.gz  \
# Unnamed: 0                         ...
# 1007_s_at                          ...                0.239554
# 1053_at                            ...               -0.008531
# 117_at                             ...               -0.003613
# 121_at                             ...                0.021700
# 1255_g_at                          ...               -0.123951
# 1294_at                            ...                0.470964
# 1316_at                            ...               -0.076115
# 1320_at                            ...                0.052318
# 1431_at                            ...                0.102390
# 1438_at                            ...                0.191635
# 1487_at                            ...               -0.107814
# 1494_f_at                          ...                0.014308
# 1598_g_at                          ...                0.116395
# 160020_at                          ...               -0.005225
# 1729_at                            ...                0.200874
# 177_at                             ...                0.535485
# 1773_at                            ...                0.386522
# 1861_at                            ...                0.548771
# 200000_s_at                        ...               -0.004508
# 200001_at                          ...                0.709242
# 200002_at                          ...               -0.223434
# 200003_s_at                        ...                0.057214
# 200004_at                          ...               -0.187084
# 200005_at                          ...               -0.146955
# 200006_at                          ...               -0.113800
# 200007_at                          ...                0.179027
# 200008_s_at                        ...                0.250048
# 200009_at                          ...                0.191954
# 200010_at                          ...                0.144772
# 200011_s_at                        ...               -0.024790
# ...                                ...                     ...
# AFFX-HUMISGF3A/M97935_5_at         ...               -0.425724
# AFFX-HUMISGF3A/M97935_MA_at        ...               -0.111866
# AFFX-HUMISGF3A/M97935_MB_at        ...                0.110710
# AFFX-HUMRGE/M10098_3_at            ...               -0.288830
# AFFX-HUMRGE/M10098_5_at            ...               -0.356362
# AFFX-HUMRGE/M10098_M_at            ...               -0.449438
# AFFX-M27830_3_at                   ...                0.020702
# AFFX-M27830_5_at                   ...               -0.480149
# AFFX-M27830_M_at                   ...               -0.469445
# AFFX-r2-Bs-dap-3_at                ...                0.017698
# AFFX-r2-Bs-dap-5_at                ...               -0.101797
# AFFX-r2-Bs-dap-M_at                ...               -0.157480
# AFFX-r2-Bs-lys-3_at                ...               -0.143723
# AFFX-r2-Bs-lys-5_at                ...               -0.140699
# AFFX-r2-Bs-lys-M_at                ...               -0.100520
# AFFX-r2-Bs-phe-3_at                ...               -0.227022
# AFFX-r2-Bs-phe-5_at                ...               -0.123866
# AFFX-r2-Bs-phe-M_at                ...               -0.228986
# AFFX-r2-Bs-thr-3_s_at              ...               -0.142035
# AFFX-r2-Bs-thr-5_s_at              ...               -0.033018
# AFFX-r2-Bs-thr-M_s_at              ...               -0.169883
# AFFX-r2-Ec-bioB-3_at               ...               -0.099279
# AFFX-r2-Ec-bioB-5_at               ...               -0.655638
# AFFX-r2-Ec-bioB-M_at               ...               -0.247979
# AFFX-r2-Ec-bioC-3_at               ...               -0.183325
# AFFX-r2-Ec-bioC-5_at               ...               -0.018430
# AFFX-r2-Ec-bioD-3_at               ...                1.113924
# AFFX-r2-Ec-bioD-5_at               ...                1.446739
# AFFX-r2-P1-cre-3_at                ...               -5.891634
# AFFX-r2-P1-cre-5_at                ...               -6.399580
#
#                              GSM48660.CEL.gz  GSM48661.CEL.gz  \
# Unnamed: 0
# 1007_s_at                           0.296144         0.356331
# 1053_at                             0.311485        -0.667259
# 117_at                             -0.371451         0.026594
# 121_at                              0.298814         0.000417
# 1255_g_at                           0.017269         0.065775
# 1294_at                            -0.270622         0.222084
# 1316_at                            -0.053057        -0.043768
# 1320_at                             0.091057         0.115051
# 1431_at                             0.116667         0.234336
# 1438_at                             0.173617         0.320945
# 1487_at                            -0.143471        -0.155104
# 1494_f_at                           0.106670         0.327916
# 1598_g_at                           0.226061         0.119267
# 160020_at                           0.197247         0.077460
# 1729_at                            -0.325058         0.031173
# 177_at                             -0.343520         0.041093
# 1773_at                             0.126326         0.457419
# 1861_at                             0.111406         0.287122
# 200000_s_at                         0.442443        -0.147350
# 200001_at                           0.381660         0.075966
# 200002_at                          -0.037081         0.199949
# 200003_s_at                        -0.157301         0.183736
# 200004_at                           0.303864        -0.028609
# 200005_at                           0.292641        -0.450812
# 200006_at                          -0.154494        -0.081362
# 200007_at                          -0.022219        -0.274853
# 200008_s_at                         0.613091         0.061667
# 200009_at                          -0.139343        -0.195367
# 200010_at                           0.159649         0.134482
# 200011_s_at                         0.380222        -0.160274
# ...                                      ...              ...
# AFFX-HUMISGF3A/M97935_5_at          0.927763         0.157036
# AFFX-HUMISGF3A/M97935_MA_at         1.120349         0.241663
# AFFX-HUMISGF3A/M97935_MB_at         1.219658         0.240648
# AFFX-HUMRGE/M10098_3_at            -0.000781        -0.149004
# AFFX-HUMRGE/M10098_5_at             0.237917        -0.103528
# AFFX-HUMRGE/M10098_M_at             0.072050        -0.183081
# AFFX-M27830_3_at                    0.146113         0.082597
# AFFX-M27830_5_at                    1.429027         0.030729
# AFFX-M27830_M_at                    0.594979         0.005317
# AFFX-r2-Bs-dap-3_at                -0.169647        -0.018663
# AFFX-r2-Bs-dap-5_at                 0.049055        -0.042058
# AFFX-r2-Bs-dap-M_at                 0.104978        -0.053120
# AFFX-r2-Bs-lys-3_at                -0.140500         0.024934
# AFFX-r2-Bs-lys-5_at                 0.094130        -0.061518
# AFFX-r2-Bs-lys-M_at                 0.078991         0.064758
# AFFX-r2-Bs-phe-3_at                -0.198594         0.030843
# AFFX-r2-Bs-phe-5_at                -0.131432        -0.066581
# AFFX-r2-Bs-phe-M_at                 0.103141        -0.171352
# AFFX-r2-Bs-thr-3_s_at              -0.300864         0.264055
# AFFX-r2-Bs-thr-5_s_at              -0.227220         0.023799
# AFFX-r2-Bs-thr-M_s_at               0.059422         0.077774
# AFFX-r2-Ec-bioB-3_at               -0.208910        -0.763627
# AFFX-r2-Ec-bioB-5_at               -0.309421        -1.113909
# AFFX-r2-Ec-bioB-M_at               -0.654075        -1.327809
# AFFX-r2-Ec-bioC-3_at               -0.179196        -0.967162
# AFFX-r2-Ec-bioC-5_at               -0.206080        -1.403406
# AFFX-r2-Ec-bioD-3_at                1.101058         0.477689
# AFFX-r2-Ec-bioD-5_at                1.269746         0.370784
# AFFX-r2-P1-cre-3_at                -6.097937        -6.030417
# AFFX-r2-P1-cre-5_at                -6.295858        -6.250333
#
#                              GSM48662.CEL.gz  GSM48663.CEL.gz  \
# Unnamed: 0
# 1007_s_at                           0.608040        -0.280956
# 1053_at                             0.013964         0.045706
# 117_at                             -0.659379        -0.328549
# 121_at                              0.330612         0.585598
# 1255_g_at                           0.025562         0.015776
# 1294_at                             0.119848        -0.070430
# 1316_at                             0.123365         0.091698
# 1320_at                             0.081394        -0.009740
# 1431_at                             0.142352         0.245961
# 1438_at                            -0.001161         0.361739
# 1487_at                            -0.150492         0.111292
# 1494_f_at                           0.317815         0.299458
# 1598_g_at                           0.085131         0.412486
# 160020_at                           0.171610         0.261757
# 1729_at                            -0.239826        -0.329012
# 177_at                             -0.122569         0.226116
# 1773_at                             0.088345        -0.132610
# 1861_at                            -0.025532         0.037769
# 200000_s_at                         0.451835         0.194204
# 200001_at                           0.207862         0.426699
# 200002_at                          -0.092214         0.022409
# 200003_s_at                        -0.004168        -0.030480
# 200004_at                           0.281023         0.355326
# 200005_at                           0.009394         0.458932
# 200006_at                          -0.076302         0.058697
# 200007_at                           0.121814         0.013924
# 200008_s_at                         0.682444         0.784664
# 200009_at                          -0.125663        -0.165491
# 200010_at                           0.304910         0.440137
# 200011_s_at                         0.028428         0.265755
# ...                                      ...              ...
# AFFX-HUMISGF3A/M97935_5_at          0.769398        -0.089662
# AFFX-HUMISGF3A/M97935_MA_at         1.096665        -0.128494
# AFFX-HUMISGF3A/M97935_MB_at         1.116471        -0.010871
# AFFX-HUMRGE/M10098_3_at             0.123913         1.731782
# AFFX-HUMRGE/M10098_5_at             0.116828         1.277070
# AFFX-HUMRGE/M10098_M_at            -0.048870         1.391700
# AFFX-M27830_3_at                    0.039741         0.435659
# AFFX-M27830_5_at                    1.821831         2.166321
# AFFX-M27830_M_at                    0.885353         1.605314
# AFFX-r2-Bs-dap-3_at                 0.075512         0.006436
# AFFX-r2-Bs-dap-5_at                -0.128023         0.109796
# AFFX-r2-Bs-dap-M_at                -0.172643        -0.040056
# AFFX-r2-Bs-lys-3_at                -0.111215        -0.033105
# AFFX-r2-Bs-lys-5_at                -0.093606        -0.167794
# AFFX-r2-Bs-lys-M_at                 0.217754        -0.072056
# AFFX-r2-Bs-phe-3_at                -0.267640         0.169331
# AFFX-r2-Bs-phe-5_at                 0.008462        -0.077309
# AFFX-r2-Bs-phe-M_at                -0.087042        -0.036050
# AFFX-r2-Bs-thr-3_s_at              -0.027815        -0.332526
# AFFX-r2-Bs-thr-5_s_at              -0.047347        -0.182237
# AFFX-r2-Bs-thr-M_s_at               0.364453         0.065155
# AFFX-r2-Ec-bioB-3_at                0.142606         0.404152
# AFFX-r2-Ec-bioB-5_at                0.054604         0.125103
# AFFX-r2-Ec-bioB-M_at               -0.405920        -0.036572
# AFFX-r2-Ec-bioC-3_at               -0.016005         0.324121
# AFFX-r2-Ec-bioC-5_at               -0.041903         0.304975
# AFFX-r2-Ec-bioD-3_at                1.201915         1.314218
# AFFX-r2-Ec-bioD-5_at                1.388541         1.573584
# AFFX-r2-P1-cre-3_at                -5.882476        -5.887450
# AFFX-r2-P1-cre-5_at                -6.283573        -6.208557
#
#                              GSM48664.CEL.gz  GSM48665.CEL.gz  \
# Unnamed: 0
# 1007_s_at                           0.141330        -0.013254
# 1053_at                            -0.056219         0.080203
# 117_at                              0.166231         0.012716
# 121_at                              0.210887         0.036463
# 1255_g_at                           0.108846         0.299192
# 1294_at                             0.035018         0.115870
# 1316_at                            -0.018328        -0.081443
# 1320_at                            -0.081915        -0.014233
# 1431_at                             0.056870        -0.059084
# 1438_at                            -0.118208        -0.116108
# 1487_at                            -0.106655         0.295234
# 1494_f_at                          -0.146224        -0.146366
# 1598_g_at                           0.156198         0.170447
# 160020_at                           0.104437         0.094489
# 1729_at                            -0.348119         0.051395
# 177_at                             -0.493421        -0.306481
# 1773_at                             0.072345        -0.078092
# 1861_at                             0.047127        -0.071849
# 200000_s_at                         0.467066         0.083472
# 200001_at                           0.276705         0.303623
# 200002_at                          -0.068889         0.068967
# 200003_s_at                         0.051295         0.033440
# 200004_at                          -0.435248        -0.183066
# 200005_at                           0.214030         0.124292
# 200006_at                           0.144557        -0.040114
# 200007_at                          -0.149868         0.115295
# 200008_s_at                        -0.174173         0.313183
# 200009_at                          -0.033211         0.088208
# 200010_at                           0.062230         0.177110
# 200011_s_at                        -0.022108        -0.062073
# ...                                      ...              ...
# AFFX-HUMISGF3A/M97935_5_at         -0.734589         0.564065
# AFFX-HUMISGF3A/M97935_MA_at        -0.490927         0.388000
# AFFX-HUMISGF3A/M97935_MB_at        -0.832221         0.180778
# AFFX-HUMRGE/M10098_3_at            -0.402470        -0.335686
# AFFX-HUMRGE/M10098_5_at            -0.270934        -0.182898
# AFFX-HUMRGE/M10098_M_at            -0.368242        -0.303169
# AFFX-M27830_3_at                    0.123752         0.308974
# AFFX-M27830_5_at                   -1.048665        -0.456902
# AFFX-M27830_M_at                   -0.177394         0.199649
# AFFX-r2-Bs-dap-3_at                -0.049450         0.175559
# AFFX-r2-Bs-dap-5_at                -0.023270         0.089759
# AFFX-r2-Bs-dap-M_at                -0.060299         0.096582
# AFFX-r2-Bs-lys-3_at                 0.581119         0.079893
# AFFX-r2-Bs-lys-5_at                 0.081456         0.094579
# AFFX-r2-Bs-lys-M_at                 0.177063         0.124578
# AFFX-r2-Bs-phe-3_at                 0.185350        -0.147686
# AFFX-r2-Bs-phe-5_at                 0.085621         0.005334
# AFFX-r2-Bs-phe-M_at                 0.114462        -0.027860
# AFFX-r2-Bs-thr-3_s_at              -0.523371         0.249948
# AFFX-r2-Bs-thr-5_s_at              -0.468678        -0.267993
# AFFX-r2-Bs-thr-M_s_at               0.305583        -0.080418
# AFFX-r2-Ec-bioB-3_at                1.759882         1.658727
# AFFX-r2-Ec-bioB-5_at                2.032491         1.936096
# AFFX-r2-Ec-bioB-M_at                1.907405         1.664315
# AFFX-r2-Ec-bioC-3_at                1.826452         1.731417
# AFFX-r2-Ec-bioC-5_at                1.951118         1.793755
# AFFX-r2-Ec-bioD-3_at                1.025028         0.815830
# AFFX-r2-Ec-bioD-5_at                1.037910         0.849286
# AFFX-r2-P1-cre-3_at                 2.920607         3.045883
# AFFX-r2-P1-cre-5_at                 2.749324         2.898310
#
#                              GSM136725.CEL.gz  GSM136726.CEL.gz  \
# Unnamed: 0
# 1007_s_at                            0.226624          0.547526
# 1053_at                              0.442193          0.125379
# 117_at                              -0.356936         -0.366887
# 121_at                              -0.083972         -0.058733
# 1255_g_at                            0.041912         -0.028842
# 1294_at                              0.006071         -0.476972
# 1316_at                             -0.035033         -0.080025
# 1320_at                              0.051340          0.011580
# 1431_at                              0.039648          0.040371
# 1438_at                              0.100176          0.113679
# 1487_at                             -0.275490         -0.158363
# 1494_f_at                            0.338504          0.091524
# 1598_g_at                           -0.194331         -0.192818
# 160020_at                           -0.064286          0.066599
# 1729_at                             -0.009477         -0.026598
# 177_at                               1.150306          1.788515
# 1773_at                              0.134444          0.047478
# 1861_at                             -0.066092          0.007074
# 200000_s_at                          0.317226         -0.205973
# 200001_at                            0.409953          0.219637
# 200002_at                            0.112094         -0.236404
# 200003_s_at                         -0.020404         -0.374950
# 200004_at                           -0.002073          0.329986
# 200005_at                           -0.029875          0.251427
# 200006_at                            0.124440          0.200914
# 200007_at                           -0.024986         -0.164052
# 200008_s_at                          0.197748          0.147454
# 200009_at                           -0.083734          0.017949
# 200010_at                            0.271649          0.158844
# 200011_s_at                          0.491631          0.597224
# ...                                       ...               ...
# AFFX-HUMISGF3A/M97935_5_at           0.934075          1.679507
# AFFX-HUMISGF3A/M97935_MA_at          0.904798          1.684933
# AFFX-HUMISGF3A/M97935_MB_at          0.999756          1.780536
# AFFX-HUMRGE/M10098_3_at             -0.148182         -0.554492
# AFFX-HUMRGE/M10098_5_at             -0.358735         -0.375940
# AFFX-HUMRGE/M10098_M_at             -0.429428         -0.381790
# AFFX-M27830_3_at                    -0.088266          0.025944
# AFFX-M27830_5_at                    -0.493143         -0.432548
# AFFX-M27830_M_at                    -0.534150         -0.435283
# AFFX-r2-Bs-dap-3_at                  0.024451         -0.083145
# AFFX-r2-Bs-dap-5_at                 -0.077226         -0.117404
# AFFX-r2-Bs-dap-M_at                 -0.159853         -0.118349
# AFFX-r2-Bs-lys-3_at                  0.009216         -0.079829
# AFFX-r2-Bs-lys-5_at                 -0.139248         -0.103871
# AFFX-r2-Bs-lys-M_at                 -0.229158         -0.081942
# AFFX-r2-Bs-phe-3_at                 -0.063116         -0.229723
# AFFX-r2-Bs-phe-5_at                 -0.073514         -0.063811
# AFFX-r2-Bs-phe-M_at                 -0.053318         -0.095074
# AFFX-r2-Bs-thr-3_s_at                0.084335         -0.052420
# AFFX-r2-Bs-thr-5_s_at                0.036463         -0.099387
# AFFX-r2-Bs-thr-M_s_at                0.298002          0.101644
# AFFX-r2-Ec-bioB-3_at                -0.964719         -1.361212
# AFFX-r2-Ec-bioB-5_at                -1.090779         -1.677262
# AFFX-r2-Ec-bioB-M_at                -1.211739         -1.813716
# AFFX-r2-Ec-bioC-3_at                -1.081072         -1.767866
# AFFX-r2-Ec-bioC-5_at                -0.917992         -1.975179
# AFFX-r2-Ec-bioD-3_at                 0.394290         -0.025613
# AFFX-r2-Ec-bioD-5_at                 0.365971         -0.145793
# AFFX-r2-P1-cre-3_at                 -5.791306         -6.054408
# AFFX-r2-P1-cre-5_at                 -6.378873         -6.296143
#
#                              GSM136727.CEL.gz
# Unnamed: 0
# 1007_s_at                           -0.128887
# 1053_at                              0.205564
# 117_at                              -0.202251
# 121_at                               0.191626
# 1255_g_at                            0.091189
# 1294_at                             -0.425343
# 1316_at                             -0.077043
# 1320_at                              0.117273
# 1431_at                              0.103739
# 1438_at                              0.088857
# 1487_at                             -0.063841
# 1494_f_at                            0.142271
# 1598_g_at                            0.128573
# 160020_at                           -0.019263
# 1729_at                             -0.099454
# 177_at                              -0.377190
# 1773_at                              0.462416
# 1861_at                              0.577749
# 200000_s_at                          0.112447
# 200001_at                            0.837850
# 200002_at                           -0.029020
# 200003_s_at                         -0.189147
# 200004_at                            0.349693
# 200005_at                            0.335530
# 200006_at                           -0.035820
# 200007_at                           -0.018424
# 200008_s_at                          0.938790
# 200009_at                            0.090394
# 200010_at                            0.278028
# 200011_s_at                          0.464261
# ...                                       ...
# AFFX-HUMISGF3A/M97935_5_at           0.578693
# AFFX-HUMISGF3A/M97935_MA_at          0.506514
# AFFX-HUMISGF3A/M97935_MB_at          0.348168
# AFFX-HUMRGE/M10098_3_at             -0.359258
# AFFX-HUMRGE/M10098_5_at             -0.207025
# AFFX-HUMRGE/M10098_M_at             -0.439798
# AFFX-M27830_3_at                    -0.097970
# AFFX-M27830_5_at                     0.338766
# AFFX-M27830_M_at                    -0.033221
# AFFX-r2-Bs-dap-3_at                  0.026246
# AFFX-r2-Bs-dap-5_at                 -0.149762
# AFFX-r2-Bs-dap-M_at                 -0.071126
# AFFX-r2-Bs-lys-3_at                 -0.089125
# AFFX-r2-Bs-lys-5_at                 -0.126815
# AFFX-r2-Bs-lys-M_at                 -0.077886
# AFFX-r2-Bs-phe-3_at                 -0.266220
# AFFX-r2-Bs-phe-5_at                 -0.131137
# AFFX-r2-Bs-phe-M_at                 -0.299946
# AFFX-r2-Bs-thr-3_s_at                0.105377
# AFFX-r2-Bs-thr-5_s_at               -0.044237
# AFFX-r2-Bs-thr-M_s_at                0.187451
# AFFX-r2-Ec-bioB-3_at                -0.885610
# AFFX-r2-Ec-bioB-5_at                -0.821790
# AFFX-r2-Ec-bioB-M_at                -1.215761
# AFFX-r2-Ec-bioC-3_at                -0.979611
# AFFX-r2-Ec-bioC-5_at                -0.956300
# AFFX-r2-Ec-bioD-3_at                 0.792325
# AFFX-r2-Ec-bioD-5_at                 0.678804
# AFFX-r2-P1-cre-3_at                 -6.068542
# AFFX-r2-P1-cre-5_at                 -6.277759
#
# [8793 rows x 102 columns]

# %%
type(exprsCEU)
exprsCEU.head()
# Out:
#             GSM25349.CEL.gz  GSM25350.CEL.gz  GSM25356.CEL.gz  \
# Unnamed: 0
# 1007_s_at          0.365059        -0.012149        -0.327827
# 1053_at           -0.136032        -0.257178        -0.027254
# 117_at            -0.490556        -0.530031        -0.232926
# 121_at             0.418026         0.364847         0.042362
# 1255_g_at          0.018335        -0.022187        -0.115002
#
#             GSM25357.CEL.gz  GSM25358.CEL.gz  GSM25359.CEL.gz  \
# Unnamed: 0
# 1007_s_at         -0.116687        -0.170685        -0.220769
# 1053_at            0.347260         0.197144         0.053000
# 117_at            -0.337577        -0.262080        -0.540250
# 121_at             0.240113         0.130720        -0.343165
# 1255_g_at          0.020611        -0.025980         0.090351
#
#             GSM25360.CEL.gz  GSM25361.CEL.gz  GSM25377.CEL.gz  \
# Unnamed: 0
# 1007_s_at         -0.211580        -0.198109        -0.035849
# 1053_at           -0.324497        -0.238930        -0.337195
# 117_at            -0.288228        -0.120475         1.085317
# 121_at            -0.322852        -0.461611         0.073949
# 1255_g_at         -0.019693        -0.088959         0.170104
#
#             GSM25378.CEL.gz        ...         GSM48658.CEL.gz  \
# Unnamed: 0                         ...
# 1007_s_at          0.096327        ...                0.239554
# 1053_at            0.292678        ...               -0.008531
# 117_at             0.878655        ...               -0.003613
# 121_at            -0.027296        ...                0.021700
# 1255_g_at         -0.246015        ...               -0.123951
#
#             GSM48660.CEL.gz  GSM48661.CEL.gz  GSM48662.CEL.gz  \
# Unnamed: 0
# 1007_s_at          0.296144         0.356331         0.608040
# 1053_at            0.311485        -0.667259         0.013964
# 117_at            -0.371451         0.026594        -0.659379
# 121_at             0.298814         0.000417         0.330612
# 1255_g_at          0.017269         0.065775         0.025562
#
#             GSM48663.CEL.gz  GSM48664.CEL.gz  GSM48665.CEL.gz  \
# Unnamed: 0
# 1007_s_at         -0.280956         0.141330        -0.013254
# 1053_at            0.045706        -0.056219         0.080203
# 117_at            -0.328549         0.166231         0.012716
# 121_at             0.585598         0.210887         0.036463
# 1255_g_at          0.015776         0.108846         0.299192
#
#             GSM136725.CEL.gz  GSM136726.CEL.gz  GSM136727.CEL.gz
# Unnamed: 0
# 1007_s_at           0.226624          0.547526         -0.128887
# 1053_at             0.442193          0.125379          0.205564
# 117_at             -0.356936         -0.366887         -0.202251
# 121_at             -0.083972         -0.058733          0.191626
# 1255_g_at           0.041912         -0.028842          0.091189
#
# [5 rows x 102 columns]

# %% [markdown]
# Using this mean normalized gene expression data, compute the projection to the first Principal Component (PC1).
#
# **Hint**: Use the `numpy.linalg.svd()` function in the `numpy.linalg` module (or the `scipy.linalg.svd()` function in the `scipy.linalg` module) to apply an [singular value decomposition](http://en.wikipedia.org/wiki/Singular_value_decomposition) to a matrix.

# %%
#your code here
U, s, Vh = lin.svd(exprsCEU, full_matrices=True)

# %%
print U.shape, s.shape, Vh.shape
# Out:
# (8793, 8793) (102,) (102, 102)

# %%
## use sklearn pca function:
from sklearn.decomposition import PCA
pca1 = PCA(n_components = 2)
pca1.fit(exprsCEU)
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
for c in pca1.components_:
    print c.shape
print pca1.explained_variance_ratio_
# Out:
# (102,)
# (102,)
# [ 0.14044342  0.11108812]

# %%
exprsCEU_comp = pca1.transform(exprsCEU)
print exprsCEU_comp.shape
pd.DataFrame(exprsCEU_comp).head(10)
# Out:
# (8793, 2)
#           0         1
# 0 -0.785738  0.465369
# 1 -1.753882  0.080078
# 2  2.401481  0.692786
# 3 -0.842330  2.107045
# 4  0.374007  0.460555
# 5  1.517351 -0.551278
# 6  0.471771  0.603755
# 7  0.151438  0.577862
# 8 -0.007977  0.654248
# 9 -0.536440  0.954032

# %%
exprsCEU_comp[:,0]
# Out:
# array([ -0.78573795,  -1.75388211,   2.401481  , ...,  -2.58167505,
#         24.05886673,  24.32585477])

# %% [markdown]
# Create a histogram using the values from PC1.  Use a bin size of 25.

# %%
#your code here
plt.hist(pca1.components_[0], bins = 25)
#plt.hist(exprsCEU_comp[:,0], bins = 25)
# Out:
# (array([ 2.,  0.,  3.,  4.,  9.,  3.,  7.,  5.,  8.,  6.,  1.,  3.,  2.,
#          8.,  4.,  6.,  7.,  8.,  3.,  3.,  4.,  1.,  2.,  0.,  3.]),
#  array([-0.19203583, -0.1757608 , -0.15948577, -0.14321074, -0.12693571,
#         -0.11066068, -0.09438565, -0.07811062, -0.06183559, -0.04556056,
#         -0.02928553, -0.0130105 ,  0.00326453,  0.01953956,  0.03581459,
#          0.05208962,  0.06836465,  0.08463968,  0.10091471,  0.11718975,
#          0.13346478,  0.14973981,  0.16601484,  0.18228987,  0.1985649 ,
#          0.21483993]),
#  <a list of 25 Patch objects>)

# %% [markdown]
# Create a scatter plot with the days since October 31, 2002 on the x-axis and PC1 on the y-axis.

# %%
#your code here
plt.scatter(sampleinfoCEU['elapsedInDays'].astype('timedelta64[D]').astype(int), pca1.components_[0])

# %% [markdown]
# Around what day do you notice a difference in the way the samples were processed?

# %%
#your code here
plt.scatter(sampleinfoCEU['elapsedInDays'].astype('timedelta64[D]').astype(int), pca1.components_[0])
plt.xlim(0,160)
# Out:
# (0, 160)

# %% [markdown]
# Answer:

# %% [markdown]
# ## Discussion for Problem 1
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 2: Is there a pollster bias in presidential election polls?

# %% [markdown]
# #### Problem 2(a)
#
# The [HuffPost Pollster](http://elections.huffingtonpost.com/pollster) contains many political polls. You can access these polls from individual races as a CSV but you can also access polls through the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to access the data.
#
# Read in the polls from the [2012 Presidential Election: Barack Obama vs Mitt Romney](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama) into a pandas DataFrame called `election`. For this problem, you may read in the polls for this race directly using [the CSV file](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv) available from the HuffPost Pollster page.

# %%
#your code here
election = pd.read_csv('http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv')

# %% [markdown]
# Show the head of the `election` DataFrame.

# %%
election = election.sort_values(by = ['Pollster', 'Start Date'])
#your code here
print election.shape
print election.dtypes
election.head()
# Out:
# (590, 17)
# Pollster                   object
# Start Date                 object
# End Date                   object
# Entry Date/Time (ET)       object
# Number of Observations    float64
# Population                 object
# Mode                       object
# Obama                     float64
# Romney                    float64
# Undecided                 float64
# Other                     float64
# Pollster URL               object
# Source URL                 object
# Partisan                   object
# Affiliation                object
# Question Text             float64
# Question Iteration          int64
# dtype: object
#      Pollster  Start Date    End Date  Entry Date/Time (ET)  \
# 537  ABC/Post  2011-04-14  2011-04-17  2011-04-19T10:29:52Z
# 524  ABC/Post  2011-06-02  2011-06-05  2011-06-07T10:35:22Z
# 510  ABC/Post  2011-07-14  2011-07-17  2011-07-19T12:46:43Z
# 492  ABC/Post  2011-08-29  2011-09-01  2011-09-06T09:22:48Z
# 480  ABC/Post  2011-09-29  2011-10-02  2011-10-04T11:37:04Z
#
#      Number of Observations         Population        Mode  Obama  Romney  \
# 537                  1001.0             Adults  Live Phone   49.0    45.0
# 524                   874.0  Registered Voters  Live Phone   46.0    49.0
# 510                     NaN  Registered Voters  Live Phone   49.0    47.0
# 492                     NaN  Registered Voters  Live Phone   45.0    49.0
# 480                     NaN  Registered Voters  Live Phone   46.0    48.0
#
#      Undecided  Other                                       Pollster URL  \
# 537        3.0    3.0  http://elections.huffingtonpost.com/pollster/p...
# 524        3.0    2.0  http://elections.huffingtonpost.com/pollster/p...
# 510        2.0    2.0  http://elections.huffingtonpost.com/pollster/p...
# 492        4.0    2.0  http://elections.huffingtonpost.com/pollster/p...
# 480        3.0    2.0  http://elections.huffingtonpost.com/pollster/p...
#
#                                             Source URL     Partisan  \
# 537  http://www.washingtonpost.com/wp-srv/politics/...  Nonpartisan
# 524  http://www.washingtonpost.com/wp-srv/politics/...  Nonpartisan
# 510  http://www.washingtonpost.com/wp-srv/politics/...  Nonpartisan
# 492  http://www.washingtonpost.com/wp-srv/politics/...  Nonpartisan
# 480  http://www.washingtonpost.com/wp-srv/politics/...  Nonpartisan
#
#     Affiliation  Question Text  Question Iteration
# 537        None            NaN                   1
# 524        None            NaN                   1
# 510        None            NaN                   1
# 492        None            NaN                   1
# 480        None            NaN                   1

# %% [markdown]
# How many polls were conducted in November? Define this number as M.
#
# **Hint**: Subset the `election` DataFrame for only dates in the `Start Date` column that are in November 2012.

# %%
#your code here
M = election[(pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).month == 11)
        & (pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).year == 2012)
        ].shape[0]
M
# Out:
# 19

# %% [markdown]
# Answer:

# %% [markdown]
# What was the median of the number of observations in the November polls? Define this quantity as N.

# %%
#your code here
N = election[(pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).month == 11)
        & (pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).year == 2012)
        ]['Number of Observations'].median()
print N
# Out:
# 1200.0

# %% [markdown]
# Answer:

# %% [markdown]
# #### Problem 2(b)
#
# Using the median sample size $N$ from Problem 1(a), simulate the results from a single poll:  simulate the number of votes for Obama out of a sample size $N$ where $p$ = 0.53 is the percent of voters who are voting for Obama.
#
# **Hint**: Use the binomial distribution with parameters $N$ and $p$ = 0.53.

# %%
#your code here
np.random.binomial(N, p=0.53)
# Out:
# 606

# %% [markdown]
# Now, perform a Monte Carlo simulation to obtain the estimated percentage of Obama votes with a sample size $N$ where $N$ is the median sample size calculated in Problem 2(a). Let $p$=0.53 be the percent of voters are voting for Obama.
#
# **Hint**: You will repeat the simulation above 1,000 times and plot the distribution of the estimated *percent* of Obama votes from a single poll.  The results from the single poll you simulate is random variable and will be different every time you sample.

# %%
#your code here
sim_1 = np.random.binomial(N, p=0.53, size = 1000)/float(N)

# %%
sim_1
# Out:
# array([ 0.56833333,  0.56666667,  0.52833333,  0.525     ,  0.52833333,
#         0.52      ,  0.53916667,  0.53583333,  0.545     ,  0.53833333,
#         0.51916667,  0.53      ,  0.51666667,  0.53166667,  0.535     ,
#         0.505     ,  0.53333333,  0.52583333,  0.54166667,  0.54166667,
#         0.54583333,  0.55333333,  0.50083333,  0.5375    ,  0.5525    ,
#         0.54333333,  0.53583333,  0.53833333,  0.53166667,  0.53833333,
#         0.53583333,  0.5325    ,  0.5475    ,  0.55333333,  0.55416667,
#         0.5325    ,  0.51166667,  0.51833333,  0.5225    ,  0.5425    ,
#         0.5325    ,  0.51166667,  0.55166667,  0.54      ,  0.515     ,
#         0.5275    ,  0.52583333,  0.53666667,  0.52916667,  0.53583333,
#         0.52666667,  0.51416667,  0.54666667,  0.5275    ,  0.53583333,
#         0.55166667,  0.54166667,  0.5375    ,  0.52666667,  0.51666667,
#         0.54416667,  0.53083333,  0.51916667,  0.53166667,  0.52333333,
#         0.51333333,  0.52666667,  0.52833333,  0.545     ,  0.52      ,
#         0.54583333,  0.52416667,  0.53333333,  0.5225    ,  0.52833333,
#         0.535     ,  0.51583333,  0.52916667,  0.51      ,  0.5075    ,
#         0.53083333,  0.55583333,  0.50666667,  0.52666667,  0.52916667,
#         0.51666667,  0.56583333,  0.51833333,  0.53166667,  0.54083333,
#         0.52      ,  0.52416667,  0.51583333,  0.54583333,  0.4925    ,
#         0.55333333,  0.53      ,  0.54083333,  0.53833333,  0.53166667,
#         0.52333333,  0.56833333,  0.53833333,  0.53916667,  0.52916667,
#         0.51583333,  0.5425    ,  0.54833333,  0.55333333,  0.51333333,
#         0.52083333,  0.53416667,  0.52666667,  0.52416667,  0.52583333,
#         0.5175    ,  0.52      ,  0.53666667,  0.53916667,  0.51833333,
#         0.525     ,  0.55916667,  0.49916667,  0.5275    ,  0.54083333,
#         0.52916667,  0.52916667,  0.54166667,  0.54166667,  0.54166667,
#         0.5275    ,  0.51      ,  0.54416667,  0.54083333,  0.54333333,
#         0.52666667,  0.53416667,  0.52833333,  0.53583333,  0.53666667,
#         0.535     ,  0.52416667,  0.53916667,  0.52416667,  0.55416667,
#         0.5325    ,  0.53083333,  0.54833333,  0.54083333,  0.53833333,
#         0.52083333,  0.52416667,  0.54166667,  0.535     ,  0.53166667,
#         0.545     ,  0.545     ,  0.51      ,  0.535     ,  0.50916667,
#         0.535     ,  0.51916667,  0.52416667,  0.5275    ,  0.54666667,
#         0.50583333,  0.53083333,  0.5075    ,  0.52583333,  0.5275    ,
#         0.545     ,  0.545     ,  0.54      ,  0.53166667,  0.54333333,
#         0.52083333,  0.52583333,  0.54833333,  0.53083333,  0.57833333])

# %% [markdown]
# Plot the distribution of the estimated percentage of Obama votes from your single poll. What is the distribution of the estimated percentage of Obama votes?

# %%
#your code here
plt.hist(sim_1)
# Out:
# (array([   8.,   26.,   79.,  178.,  245.,  225.,  158.,   54.,   21.,    6.]),
#  array([ 0.48416667,  0.49358333,  0.503     ,  0.51241667,  0.52183333,
#          0.53125   ,  0.54066667,  0.55008333,  0.5595    ,  0.56891667,
#          0.57833333]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Answer:

# %% [markdown]
# What is the standard error (SE) of the estimated percentage from the poll.
#
# **Hint**: Remember the SE is the standard deviation (SD) of the distribution of a random variable.

# %%
#your code here
np.std(sim_1)
# Out:
# 0.014858917636669685

# %% [markdown]
# #### Problem 2(c)
#
# Now suppose we run M polls where M is the number of polls that happened in November (calculated in Problem 2(a)). Run 1,000 simulations and compute the mean of the M polls for each simulation.

# %%
M
# Out:
# 19

# %%
sim_2 = [(np.random.binomial(p = 0.53, n = N, size = M)/float(N)).mean() for i in xrange(1000)]
sim_2
# Out:
# [0.53508771929824561,
#  0.53504385964912271,
#  0.52565789473684199,
#  0.53372807017543855,
#  0.53276315789473683,
#  0.53324561403508763,
#  0.53083333333333338,
#  0.52850877192982459,
#  0.52951754385964911,
#  0.53157894736842093,
#  0.5311842105263157,
#  0.53298245614035078,
#  0.53390350877192982,
#  0.53736842105263161,
#  0.52600877192982465,
#  0.52671052631578952,
#  0.53135964912280698,
#  0.53021929824561409,
#  0.53372807017543866,
#  0.5278508771929824,
#  0.52991228070175433,
#  0.53258771929824567,
#  0.52872807017543866,
#  0.53403508771929831,
#  0.52885964912280692,
#  0.52583333333333337,
#  0.53232456140350881,
#  0.52824561403508774,
#  0.53508771929824572,
#  0.53004385964912282,
#  0.52986842105263166,
#  0.52877192982456145,
#  0.52293859649122809,
#  0.52995614035087701,
#  0.5317982456140351,
#  0.53307017543859647,
#  0.5301315789473684,
#  0.53004385964912282,
#  0.53201754385964917,
#  0.5279385964912281,
#  0.53267543859649114,
#  0.52758771929824566,
#  0.52859649122807018,
#  0.5307456140350878,
#  0.52916666666666656,
#  0.53074561403508769,
#  0.53429824561403505,
#  0.52850877192982459,
#  0.52745614035087729,
#  0.53096491228070175,
#  0.52307017543859657,
#  0.5284210526315789,
#  0.5307017543859649,
#  0.53105263157894733,
#  0.53276315789473683,
#  0.53399122807017552,
#  0.53438596491228074,
#  0.52486842105263154,
#  0.53096491228070186,
#  0.52767543859649135,
#  0.53425438596491226,
#  0.52539473684210536,
#  0.52815789473684216,
#  0.52535087719298246,
#  0.52631578947368418,
#  0.52881578947368413,
#  0.52964912280701759,
#  0.52903508771929819,
#  0.53135964912280709,
#  0.52964912280701748,
#  0.52491228070175444,
#  0.52978070175438596,
#  0.53258771929824567,
#  0.53074561403508791,
#  0.52894736842105272,
#  0.53263157894736834,
#  0.52758771929824566,
#  0.5318859649122808,
#  0.52622807017543871,
#  0.52530701754385956,
#  0.52776315789473671,
#  0.53140350877192977,
#  0.53135964912280698,
#  0.52951754385964911,
#  0.52758771929824555,
#  0.53557017543859642,
#  0.52864035087719285,
#  0.53570175438596501,
#  0.52793859649122798,
#  0.53192982456140347,
#  0.5228508771929824,
#  0.53144736842105278,
#  0.52973684210526306,
#  0.52767543859649135,
#  0.53000000000000003,
#  0.52925438596491237,
#  0.52258771929824555]

# %% [markdown]
# What is the distribution of the average of polls?
#
# **Hint**: Show a plot.

# %%
#your code here
plt.hist(sim_2)
# Out:
# (array([   4.,   23.,   60.,  159.,  251.,  239.,  175.,   64.,   23.,    2.]),
#  array([ 0.51934211,  0.5214693 ,  0.52359649,  0.52572368,  0.52785088,
#          0.52997807,  0.53210526,  0.53423246,  0.53635965,  0.53848684,
#          0.54061404]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Answer:

# %% [markdown]
# What is the standard error (SE) of the average of polls?

# %%
#your code here
np.std(sim_2)
# Out:
# 0.0031763845854529305

# %% [markdown]
# Answer:

# %% [markdown]
# Is the SE of the average of polls larger, the same, or smaller than that the SD of a single poll (calculated in Problem 2(b))? By how much?
#
# **Hint**: Compute a ratio of the two quantities.

# %%
#your code here
np.std(sim_2)/np.std(sim_1)
# Out:
# 0.21376958020240097

# %% [markdown]
# Answer:

# %% [markdown]
# #### Problem 2(d)
#
# Repeat Problem 2(c) but now record the *across poll* standard deviation in each simulation.

# %%
#your code here
sim_2_std = [(np.random.binomial(p = 0.53, n = N, size = M)/float(N)).std() for i in xrange(1000)]
len(sim_2_std)
# Out:
# 1000

# %% [markdown]
# What is the distribution of the *across M polls* standard deviation?
#
# **Hint**: Show a plot.

# %%
#your code here
plt.hist(sim_2_std)
# Out:
# (array([   1.,   25.,   76.,  162.,  209.,  233.,  153.,   90.,   37.,   14.]),
#  array([ 0.00686764,  0.00822495,  0.00958227,  0.01093958,  0.01229689,
#          0.0136542 ,  0.01501151,  0.01636883,  0.01772614,  0.01908345,
#          0.02044076]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# Answer:

# %% [markdown]
# #### Problem 2(e)
#
# What is the standard deviation of M polls in our real (not simulated) 2012 presidential election data ?

# %%
election[(pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).month == 11)
        & (pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).year == 2012)
        ]['Obama']/float(100)
# Out:
# 11    0.50
# 8     0.49
# 16    0.51
# 10    0.49
# 13    0.50
# 15    0.49
# 12    0.48
# 2     0.48
# 3     0.50
# 7     0.48
# 5     0.47
# 14    0.48
# 17    0.48
# 9     0.50
# 0     0.47
# 4     0.48
# 20    0.49
# 6     0.49
# 1     0.49
# Name: Obama, dtype: float64

# %%
#your code here
np.std(election[(pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).month == 11)
        & (pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).year == 2012)
        ]['Obama']/(float(100)))
# Out:
# 0.010552598766191284

# %% [markdown]
# Is this larger, the same, or smaller than what we expeced if polls were not biased.

# %%
#your code here
np.std(election[(pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).month == 11)
        & (pd.DatetimeIndex(pd.to_datetime(election['Start Date'])).year == 2012)
        ]['Obama']/(float(100)))/np.mean(sim_2_std)
# Out:
# 0.76224825409852015

# %% [markdown]
# Answer:

# %% [markdown]
# #### Problem 2(f)
#
# **For AC209 Students**: Learn about the normal approximation for the binomial distribution and derive the results of Problem 2(b) and 2(c) analytically (using this approximation). Compare the results obtained analytically to those obtained from simulations.

# %%
#your code here

# %% [markdown]
# Answer:

# %% [markdown]
# ## Discussion for Problem 2
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 3: Is the average of polls better than just one poll?

# %% [markdown]
# #### Problem 3(a)
#
# Most undecided voters vote for one of the two candidates at the election. Therefore, the reported percentages underestimate the final value of both candidates. However, if we assume the undecided will split evenly, then the observed difference should be an unbiased estimate of the final difference.
#
# Add a new column to the `election` DataFrame containg the difference between Obama and Romeny called `Diff`.

# %%
#your code here

# %% [markdown]
# #### Problem 3(b)
#
# Make a plot of the differences for the week before the election (e.g. 5 days) where the days are on the x-axis and the differences are on the y-axis.  Add a horizontal line showing 3.9%: the difference between Obama and Romney on election day.

# %%
#your code here

# %% [markdown]
# #### Problem 3(c)
#
# Make a plot showing the differences by pollster where the pollsters are on the x-axis and the differences on the y-axis.

# %%
#your code here

# %% [markdown]
# Is the *across poll* difference larger than the *between pollster* difference?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Problem 3(d)
#
# Take the average for each pollster and then compute the average of that. Given this difference how confident would you have been of an Obama victory?
#
# **Hint**: Compute an estimate of the SE of this average based exclusively on the observed data.

# %%
#your code here

# %% [markdown]
# Answer:

# %% [markdown]
# #### Problem 3(e)
#
# **For AC209 Students**: Show the difference against time and see if you can detect a trend towards the end. Use this trend to see if it improves the final estimate.

# %%
#your code here

# %% [markdown]
# Answer:

# %% [markdown]
# ## Discussion for Problem 3
#
# *Write a brief discussion of your conclusions to the questions and tasks above in 100 words or less.*
#
# ---

# %% [markdown]
# ## Problem 4
#
# In this last problem, we will use the polls from the [2014 Senate Midterm Elections](http://elections.huffingtonpost.com/pollster) from the [HuffPost Pollster API](http://elections.huffingtonpost.com/pollster/api) to create a preliminary prediction of the result of each state.
#
# The HuffPost Pollster API allows you to access the data as a CSV or a JSON response by tacking ".csv" or ".json" at the end of the URLs. For example the 2012 Presidential Election could be accessed as a [.json](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.json) instead of a [.csv](http://elections.huffingtonpost.com/pollster/2012-general-election-romney-vs-obama.csv)

# %% [markdown]
# #### Problem 4(a)
#
# Read in the polls for **all** of the 2014 Senate Elections using the HuffPost API. For example, we can consider the [2014 Senate race in Kentucky between Mitch McConnell and Alison Grimes](http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes).
#
# To search for the 2014 Senate races, use the `topics` parameter in the API [[read more about topics here](http://elections.huffingtonpost.com/pollster/api)].

# %%
url_str = "http://elections.huffingtonpost.com/pollster/api/charts/?topic=2014-senate"

# %% [markdown]
# To list all the URLs related to the 2014 Senate races using the pollster API, we can use a list comprehension:

# %%
election_urls = [election['url'] + '.csv' for election in requests.get(url_str).json()]
election_urls
# Out:
# [u'http://elections.huffingtonpost.com/pollster/2014-kentucky-senate-mcconnell-vs-grimes.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-arkansas-senate-cotton-vs-pryor.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-michigan-senate-land-vs-peters.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-louisiana-senate-cassidy-vs-landrieu.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-brown-vs-shaheen.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-west-virginia-senate-capito-vs-tennant.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-new-hampshire-senate-bass-vs-shaheen.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-north-carolina-senate-tillis-vs-hagan.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-virginia-senate-gillespie-vs-warner.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-colorado-senate-gardner-vs-udall.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-illinois-senate-oberweis-vs-durbin.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-alaska-senate-sullivan-vs-begich.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-iowa-senate-ernst-vs-braley.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-mississippi-senate-cochran-vs-childers.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-oregon-senate-wehby-vs-merkley.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-georgia-senate-perdue-vs-nunn.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-louisiana-senate-sasse-vs-domina.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-south-dakota-senate-rounds-vs-weiland.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-maine-senate-collins-vs-bellows.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-minnesota-senate-mcfadden-vs-franken.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-texas-senate-cornyn-vs-alameel.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-graham-vs-hutto.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-south-carolina-senate-scott-vs-dickerson.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-inhofe-vs-silverstein.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-new-mexico-senate-weh-vs-udall.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-new-jersey-senate-bell-vs-booker.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-idaho-senate-risch-vs-mitchell.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-tennessee-senate-alexander-vs-ball.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-wyoming-senate.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-kansas-senate-roberts-vs-orman-vs-taylor.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-hawaii-senate-cavasso-vs-schatz.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-oklahoma-senate-lankford-vs-johnson.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-montana-senate-daines-vs-curtis.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-rhode-island-senate-zaccaria-vs-reed.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-massachusetts-senate-herr-vs-markey.csv',
#  u'http://elections.huffingtonpost.com/pollster/2014-delaware-senate-wade-vs-coons.csv']

# %% [markdown]
# Because there so many Senate races, we can create a dictionary of pandas DataFrames that will be keyed by the name of the election (a string).

# %%
def build_frame(url):
    """
    Returns a pandas DataFrame object containing
    the data returned from the given url
    """
    source = requests.get(url).text
    
    # Use StringIO because pd.DataFrame.from_csv requires .read() method
    s = StringIO(source)
    
    return pd.DataFrame.from_csv(s, index_col=None).convert_objects(
            convert_dates="coerce", convert_numeric=True)

# %%
# Makes a dictionary of pandas DataFrames keyed on election string.
dfs = dict((election.split("/")[-1][:-4], build_frame(election)) for election in election_urls)

# %% [markdown]
# Show the head of the DataFrame containing the polls for the 2014 Senate race in Kentucky between McConnell and Grimes.

# %%
#your code here

# %% [markdown]
# #### Problem 4(b)
#
# For each 2014 Senate race, create a preliminary prediction of the result for that state.

# %%
#your code here

# %% [markdown]
# # Submission Instructions
#
# To submit your homework, create a folder named **lastname_firstinitial_hw#** and place your IPython notebooks, data files, and any other files in this folder. Your IPython Notebooks should be completely executed with the results visible in the notebook. We should not have to run any code.  Compress the folder (please use .zip compression) and submit to the CS109 dropbox in the appropriate folder. *If we cannot access your work because these directions are not followed correctly, we will not grade your work.*
